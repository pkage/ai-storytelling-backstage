# %% [markdown]
# # AIST Extras demo
#
# This shows some stuff that isn't easily categorizable into `text` or `image`, or isn't quite ready for primetime.

# %%
from aist import extras

# %% [markdown]
# ## Rank by sentiment
#
# Given a list of strings, rank them by their sentiment.

# %%
extras.rank_by_sentiment([
    'I like working here.',
    'This place is just okay, not great not terrible.',
    'Fuck this place.',
    'A fundamentally transcendental experience.',
    'This place is neutral.'
])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/pm/dvglhyn133sbzgg266kj4kqr0000gn/T/ipykernel_7017/3138933728.py in <cell line: 1>()
# ----> 1 extras.rank_by_sentiment([
#       2     'I like working here.',
#       3     'This place is just okay, not great not terrible.',
#       4     'Fuck this place.',
#       5     'A fundamentally transcendental experience.',
#
# ~/Repositories/school/phd/ai-storytelling-backstage/code/aist/extras.py in rank_by_sentiment(strings, render, seed)
#      14     results = []
#      15
# ---> 16     for string in strings:
#      17         result = sentiment_analysis(string, seed=seed, render=False)
#      18         result['original'] = string
#
# ~/Repositories/school/phd/ai-storytelling-backstage/code/aist/text.py in sentiment_analysis(text, model, seed, render)
#     179     _seed_if_necessary(seed)
#     180
# --> 181     pipe = pipeline(task='sentiment-analysis', model=model)
#     182
#     183     sentiment = pipe(text)[0]
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, model_kwargs, pipeline_class, **kwargs)
#     614                 tokenizer_kwargs = model_kwargs
#     615
# --> 616             tokenizer = AutoTokenizer.from_pretrained(
#     617                 tokenizer_identifier, revision=revision, use_fast=use_fast, _from_pipeline=task, **tokenizer_kwargs
#     618             )
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     595             tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#     596             if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 597                 return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     598             else:
#     599                 if tokenizer_class_py is not None:
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1720             else:
#    1721                 try:
# -> 1722                     resolved_vocab_files[file_id] = cached_path(
#    1723                         file_path,
#    1724                         cache_dir=cache_dir,
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/transformers/utils/hub.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     282     if is_remote_url(url_or_filename):
#     283         # URL, so get it from the cache (downloading if necessary)
# --> 284         output_path = get_from_cache(
#     285             url_or_filename,
#     286             cache_dir=cache_dir,
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/transformers/utils/hub.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     492     if not local_files_only:
#     493         try:
# --> 494             r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
#     495             _raise_for_status(r)
#     496             etag = r.headers.get("X-Linked-Etag") or r.headers.get("ETag")
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/requests/api.py in head(url, **kwargs)
#      98
#      99     kwargs.setdefault("allow_redirects", False)
# --> 100     return request("head", url, **kwargs)
#     101
#     102
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1040         # Force connect early to allow us to validate the connection.
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#    1044         if not conn.is_verified:
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     356     def connect(self):
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#     360         tls_in_tls = False
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~/Library/Caches/pypoetry/virtualenvs/aist-DH1EizW4-py3.9/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83             if source_address:
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#      87
#
# KeyboardInterrupt:
