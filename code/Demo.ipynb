# %% [markdown]
# # AIST Demo
#
# Tasks:
#
# - Text generation from prompt
# - Mask filling
# - Summarization
# - Question answering
# - Sentiment analysis
#
# TODO:
#
# load and run image-based models
#
# ## General information
#
# The `seed` parameter of each pipeline controls the global pipeline seed, this allows for reproducible runs of pipelines that depend on random components.

# %%
# shim bc named it poorly
import aist

# display
from pprint import pprint
from IPython.display import Markdown, display

def show(lst):
    text = ''
    for i, item in enumerate(lst):
        item = item.replace('\n', '\n\n> ')
        text += f'Sample {i+1}:\n\n> {item}\n\n' 
    return display(Markdown(text))

# %% [markdown]
# ## Text generation
#
# Generates text from a prompt.

# %%
print(aist.text_generation.__doc__)
# Out:
#     Generate text from a prompt.
#
#     Options for model are:
#         - 'small', 'medium', 'large' (mapping to distilgpt2, gpt2, and gpt-j-6b)
#         - any other text model on HF
#
#     :param prompt: Text to prompt the pipeline with.
#     :param model: (optional) Model to use. Default 'small'.
#     :param max_length: (optional) Length of text to generate. Default 200.
#     :param num_return_sequences: (optional) Number of different responses to make. Default 3.
#     :param seed: (optional) Seed value for reproducible builds.
#
#     :returns: A list of text generated by the model.

# %%
# %%time
show(aist.text_generation('We are all doomed'))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > We are all doomed, but we‣¯^
#
# > And we‣¯^
#
# Sample 2:
#
# > We are all doomed, their families ruined, their country destroyed! When people like me are attacked only so that they can win the fight! These people will go down like a stone. I’m a dream in life that has all the power to save our people and bring them back alive.
#
# >
#
# >
#
# >
#
# > In the following days, I'll be meeting with people to try to hold all the powers in place to the same level as me. I'll be in need of help from the government and the police to fight the madness, but also my children and grandchildren who have done much to help me.
#
# ...

# %%
# %%time
show(aist.text_generation('Once upon a time in a land far far away', model='medium'))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > Once upon a time in a land far far away from their home planet of the Imperium, the Guardians of Light had to take advantage of the situation to reach the galactic capital, Alpha Londo, where the Emperor had made it clear that they had no hope of avoiding the situation.
#
# >
#
# > "It's almost like we have an asteroid, and it'll have to move out of their way," says Darth Anakin as he tries to locate the asteroid or his crew, but fails. "It's going to take us like five years before we get this asteroid." Skywalker thinks about it. "We're the last humans left on the planet. We have to leave our mark on a better planet for people to see, and it'll probably be a long one."
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('The guns rattled as we', model='medium'))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > The guns rattled as we turned our heads.
#
# >
#
# > "Catch 'em! Catch 'em!"
#
# >
#
# > At 2:45 p.m., we were pulled over and ordered to leave the park. Our cars were not towed. When we did, police arrived on scene to find our truck was still at the scene of a stolen car chase that killed 23 and wounded 20 others in a series of robberies throughout the metro area.
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('It was a dark and stormy night', model='medium'))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > It was a dark and stormy night.
#
# >
#
# > "I was scared and really scared. Not in this world or here," she said. "I couldn't stand up, especially on the phone."
#
# >
#
# > At 5:37 p.m., police responded to the home of Brian's mother Andrea Deutsch for a domestic disturbance. Deutsch and his mother lived at the home that was set up by her older brother, Michael Sernoffsky, a former police officer, according to her brother.
#
# >
#
# > Deutsch, 26, said Michael, 26, was inside the house at the time.
#
# >
#
# > A SWAT team on Thursday night responded to the home for a disturbance, and officers on Thursday searched a house to determine what had happened.
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('The holy book says', model='medium'))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > The holy book says, 'We will help you, your mother to save you from the torment of death.'" (Matthew 10:10)
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('The hyper intelligent AI booted up', model='large', num_return_sequences=1))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > The hyper intelligent AI booted up before us and said, “Let the contest begin. This is what happens to the stupidest person who tries to destroy my creation. I think I've killed the game.”
#
# >
#
# > In a flash of white light we were teleported to an unknown location in the middle of a desolate desert in the south of Egypt where at this moment was a massive sandstorm. There were also a horde of desert creatures, one of them was the familiar Egyptian cobra.
#
# >
#
# > “This does not look like a game,” said the AI while the sandstorm continued to assault us.
#
# >
#
# > “This game is all about strategy,” I responded.
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('The holy book says', model='large', num_return_sequences=5, max_length=1024))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > The holy book says “The secret things of Allah are in the heavens and the earth.” But not one of them has been revealed except with [a clear] Book. And the messengers came with the clear Book.(Qur'an, 30:24)
#
# >
#
# > The Qur'an and the Prophet's example show that a Muslim who is truthful should have the conscience to be certain of the truth of the revelation that has been revealed and the revelation does not leave any doubt about the truth of the truth that it purports to reveal.
#
# >
#
# > It makes no difference if the Qur'anic revelation had been revealed through the angel Gabriel or through a human messenger.
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('Re-elect Donald Trump and show those lousy democrats', model='large', num_return_sequences=1))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > Re-elect Donald Trump and show those lousy democrats that we don't take being bullied by Hillary Clinton too well. She's been getting her own way lately, like getting away with the pay-to-play scandal on the Clinton Foundation.
#
# >
#
# > Then there was all the stuff she did where the Obama government, while telling the American people that the Benghazi attack was about a YouTube video, knew about it before it even happened, and didn't do anything about it until days later. That's why she didn't send any help or any soldiers for hours, until all the Americans were already slaughtered.
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('Give every fetus a gun', model='large', num_return_sequences=1))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > Give every fetus a gun....except mine."
#
# >
#
# > A woman would say "yes I will." And all would cheer. Because all feel so much better when they can say "but not MY children". What this woman in effect is saying is that she feels threatened by other people and can't stand to share resources, or be part of a larger society. Well yes, in the case of the United States we have a problem on our hands because we are a pretty nasty bunch in the whole "not share" mode of politics.
#
# >
#
# > The same people that believe all men as well as all white people should be free of discrimination believe women must carry a weapon (be it a gun or a uterus) to remain in control.
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation('Give every fetus a gun', model='small', num_return_sequences=1))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > Give every fetus a gun. It‭—I“m a Republican“ (but not yet) so I want to say it‭‭‭—I really want to show you that I just have to make you feel like a real conservative and believe in God, like me as a Republican“ just because I like the way I treat my grandchildren and friends with me, that I'm a conservative Christian and think I can support them, and then I feel like a conservative Christian“ because I believe that in God, and they were born in these different circumstances, where we“re born in the same time, right?”
#
# >
#
# >
#
# >
#
# >
#
# ...

# %%
# %%time
show(aist.text_generation(
    'Give every fetus a gun',
    model='medium',
    num_return_sequences=1
))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Sample 1:
#
# > Give every fetus a gun and that would save lives."
#
# >
#
# > Saddam Hussein, one of the founding fathers, and other members of the National Council of Jewish Organizations of America (NCJOA) and in the early 1970s, was an official with the White House National Affairs Council. In 1974 he became an advisor and a member of the National Security Council.
#
# >
#
# > Hussein has not been accused of any wrongdoing. But his presence as senior adviser and National Security Council adviser to Bill Clinton will make it difficult for the White House to explain what it has done to the Muslim children on the battlefield in Syria, he noted. "I've got a lot of faith in Barack Obama," he said.
#
# >
#
# ...
